# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install bs4==0.0.2
# !pip install langchain==0.1.17
# !pip install langchain-community==0.0.36
# !pip install langchainhub==0.1.15
# !pip install chromadb==0.5.0
# !pip install langgraph==0.0.44
# !pip install tavily-python==0.3.3
# !pip install pandas==2.2.2
# Out:
# Requirement already satisfied: bs4==0.0.2 in d:\jupyter\.venv\lib\site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in d:\jupyter\.venv\lib\site-packages (from bs4==0.0.2) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in d:\jupyter\.venv\lib\site-packages (from beautifulsoup4->bs4==0.0.2) (2.5)
# Requirement already satisfied: langchain==0.1.17 in d:\jupyter\.venv\lib\site-packages (0.1.17)
# Requirement already satisfied: PyYAML>=5.3 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (0.6.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.36 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (0.0.36)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (0.1.54)
# Requirement already satisfied: numpy<2,>=1 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in d:\jupyter\.venv\lib\site-packages (from langchain==0.1.17) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\jupyter\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\jupyter\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\jupyter\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\jupyter\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\jupyter\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\jupyter\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\jupyter\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\jupyter\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.17) (2.4)
# Requirement already satisfied: packaging<24.0,>=23.2 in d:\jupyter\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.48->langchain==0.1.17) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\jupyter\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (3.10.3)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\jupyter\.venv\lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in d:\jupyter\.venv\lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\jupyter\.venv\lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchain==0.1.17) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchain==0.1.17) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchain==0.1.17) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchain==0.1.17) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in d:\jupyter\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.17) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\jupyter\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (1.0.0)
# Requirement already satisfied: langchain-community==0.0.36 in d:\jupyter\.venv\lib\site-packages (0.0.36)
# Requirement already satisfied: PyYAML>=5.3 in d:\jupyter\.venv\lib\site-packages (from langchain-community==0.0.36) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\jupyter\.venv\lib\site-packages (from langchain-community==0.0.36) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\jupyter\.venv\lib\site-packages (from langchain-community==0.0.36) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in d:\jupyter\.venv\lib\site-packages (from langchain-community==0.0.36) (0.6.5)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in d:\jupyter\.venv\lib\site-packages (from langchain-community==0.0.36) (0.1.52)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in d:\jupyter\.venv\lib\site-packages (from langchain-community==0.0.36) (0.1.54)
# Requirement already satisfied: numpy<2,>=1 in d:\jupyter\.venv\lib\site-packages (from langchain-community==0.0.36) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in d:\jupyter\.venv\lib\site-packages (from langchain-community==0.0.36) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in d:\jupyter\.venv\lib\site-packages (from langchain-community==0.0.36) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\jupyter\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.36) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\jupyter\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.36) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\jupyter\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.36) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\jupyter\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.36) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\jupyter\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.36) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\jupyter\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.0.36) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\jupyter\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.0.36) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\jupyter\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.48->langchain-community==0.0.36) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in d:\jupyter\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.48->langchain-community==0.0.36) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in d:\jupyter\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.48->langchain-community==0.0.36) (2.7.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\jupyter\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.0.36) (3.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchain-community==0.0.36) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchain-community==0.0.36) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchain-community==0.0.36) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchain-community==0.0.36) (2024.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\jupyter\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.0.36) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in d:\jupyter\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.0.36) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in d:\jupyter\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.48->langchain-community==0.0.36) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\jupyter\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.48->langchain-community==0.0.36) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in d:\jupyter\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.48->langchain-community==0.0.36) (2.18.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\jupyter\.venv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.0.36) (1.0.0)
# Requirement already satisfied: langchainhub==0.1.15 in d:\jupyter\.venv\lib\site-packages (0.1.15)
# Requirement already satisfied: requests<3,>=2 in d:\jupyter\.venv\lib\site-packages (from langchainhub==0.1.15) (2.31.0)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in d:\jupyter\.venv\lib\site-packages (from langchainhub==0.1.15) (2.31.0.20240406)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchainhub==0.1.15) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchainhub==0.1.15) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchainhub==0.1.15) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langchainhub==0.1.15) (2024.2.2)
# Requirement already satisfied: chromadb==0.5.0 in d:\jupyter\.venv\lib\site-packages (0.5.0)
# Requirement already satisfied: build>=1.0.3 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (1.2.1)
# Requirement already satisfied: requests>=2.28 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (2.7.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (0.111.0)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\jupyter\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.0) (0.29.0)
# Requirement already satisfied: numpy>=1.22.5 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (4.11.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (1.18.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (1.24.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (0.45b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (1.24.0)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (7.7.0)
# Requirement already satisfied: importlib-resources in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (1.64.0)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (0.12.3)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in d:\jupyter\.venv\lib\site-packages (from chromadb==0.5.0) (3.10.3)
# Requirement already satisfied: packaging>=19.1 in d:\jupyter\.venv\lib\site-packages (from build>=1.0.3->chromadb==0.5.0) (23.2)
# Requirement already satisfied: pyproject_hooks in d:\jupyter\.venv\lib\site-packages (from build>=1.0.3->chromadb==0.5.0) (1.1.0)
# Requirement already satisfied: colorama in d:\jupyter\.venv\lib\site-packages (from build>=1.0.3->chromadb==0.5.0) (0.4.6)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in d:\jupyter\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb==0.5.0) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in d:\jupyter\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb==0.5.0) (0.0.4)
# Requirement already satisfied: httpx>=0.23.0 in d:\jupyter\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb==0.5.0) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in d:\jupyter\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb==0.5.0) (3.1.3)
# Requirement already satisfied: python-multipart>=0.0.7 in d:\jupyter\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb==0.5.0) (0.0.9)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in d:\jupyter\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb==0.5.0) (5.10.0)
# Requirement already satisfied: email_validator>=2.0.0 in d:\jupyter\.venv\lib\site-packages (from fastapi>=0.95.2->chromadb==0.5.0) (2.1.1)
# Requirement already satisfied: certifi>=14.05.14 in d:\jupyter\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.0) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in d:\jupyter\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.0) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in d:\jupyter\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.0) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\jupyter\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.0) (2.29.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\jupyter\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.0) (1.8.0)
# Requirement already satisfied: requests-oauthlib in d:\jupyter\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.0) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in d:\jupyter\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.0) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in d:\jupyter\.venv\lib\site-packages (from kubernetes>=28.1.0->chromadb==0.5.0) (2.2.1)
# Requirement already satisfied: coloredlogs in d:\jupyter\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.5.0) (15.0.1)
# Requirement already satisfied: flatbuffers in d:\jupyter\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.5.0) (24.3.25)
# Requirement already satisfied: protobuf in d:\jupyter\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.5.0) (4.25.3)
# Requirement already satisfied: sympy in d:\jupyter\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb==0.5.0) (1.12)
# Requirement already satisfied: deprecated>=1.2.6 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.0) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.0,>=6.0 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb==0.5.0) (7.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.0) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.24.0 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.0) (1.24.0)
# Requirement already satisfied: opentelemetry-proto==1.24.0 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==0.5.0) (1.24.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.45b0 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0) (0.45b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.45b0 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0) (0.45b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.45b0 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0) (0.45b0)
# Requirement already satisfied: opentelemetry-util-http==0.45b0 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0) (0.45b0)
# Requirement already satisfied: setuptools>=16.0 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0) (70.0.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in d:\jupyter\.venv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in d:\jupyter\.venv\lib\site-packages (from posthog>=2.4.0->chromadb==0.5.0) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in d:\jupyter\.venv\lib\site-packages (from posthog>=2.4.0->chromadb==0.5.0) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\jupyter\.venv\lib\site-packages (from pydantic>=1.9->chromadb==0.5.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in d:\jupyter\.venv\lib\site-packages (from pydantic>=1.9->chromadb==0.5.0) (2.18.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jupyter\.venv\lib\site-packages (from requests>=2.28->chromadb==0.5.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\jupyter\.venv\lib\site-packages (from requests>=2.28->chromadb==0.5.0) (3.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in d:\jupyter\.venv\lib\site-packages (from tokenizers>=0.13.2->chromadb==0.5.0) (0.23.0)
# Requirement already satisfied: click>=8.0.0 in d:\jupyter\.venv\lib\site-packages (from typer>=0.9.0->chromadb==0.5.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in d:\jupyter\.venv\lib\site-packages (from typer>=0.9.0->chromadb==0.5.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\jupyter\.venv\lib\site-packages (from typer>=0.9.0->chromadb==0.5.0) (13.7.1)
# Requirement already satisfied: h11>=0.8 in d:\jupyter\.venv\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb==0.5.0) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in d:\jupyter\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.0) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in d:\jupyter\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.0) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in d:\jupyter\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.0) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in d:\jupyter\.venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.0) (12.0)
# Requirement already satisfied: dnspython>=2.0.0 in d:\jupyter\.venv\lib\site-packages (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb==0.5.0) (2.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\jupyter\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\jupyter\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\jupyter\.venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0) (4.9)
# Requirement already satisfied: anyio in d:\jupyter\.venv\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb==0.5.0) (4.3.0)
# Requirement already satisfied: httpcore==1.* in d:\jupyter\.venv\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb==0.5.0) (1.0.5)
# Requirement already satisfied: sniffio in d:\jupyter\.venv\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb==0.5.0) (1.3.1)
# Requirement already satisfied: filelock in d:\jupyter\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.0) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\jupyter\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==0.5.0) (2024.3.1)
# Requirement already satisfied: zipp>=0.5 in d:\jupyter\.venv\lib\site-packages (from importlib-metadata<=7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==0.5.0) (3.18.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\jupyter\.venv\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb==0.5.0) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\jupyter\.venv\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\jupyter\.venv\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.0) (2.18.0)
# Requirement already satisfied: humanfriendly>=9.1 in d:\jupyter\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.0) (10.0)
# Requirement already satisfied: mpmath>=0.19 in d:\jupyter\.venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.5.0) (1.3.0)
# Requirement already satisfied: pyreadline3 in d:\jupyter\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb==0.5.0) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in d:\jupyter\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb==0.5.0) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in d:\jupyter\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb==0.5.0) (0.6.0)
# Requirement already satisfied: langgraph==0.0.44 in d:\jupyter\.venv\lib\site-packages (0.0.44)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.46 in d:\jupyter\.venv\lib\site-packages (from langgraph==0.0.44) (0.1.52)
# Requirement already satisfied: PyYAML>=5.3 in d:\jupyter\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\jupyter\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in d:\jupyter\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (0.1.54)
# Requirement already satisfied: packaging<24.0,>=23.2 in d:\jupyter\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in d:\jupyter\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (2.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in d:\jupyter\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (8.2.3)
# Requirement already satisfied: jsonpointer>=1.9 in d:\jupyter\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\jupyter\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (3.10.3)
# Requirement already satisfied: requests<3,>=2 in d:\jupyter\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\jupyter\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in d:\jupyter\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\jupyter\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\jupyter\.venv\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.46->langgraph==0.0.44) (2024.2.2)
# Requirement already satisfied: tavily-python==0.3.3 in d:\jupyter\.venv\lib\site-packages (0.3.3)
# Requirement already satisfied: requests in d:\jupyter\.venv\lib\site-packages (from tavily-python==0.3.3) (2.31.0)
# Requirement already satisfied: tiktoken<1,>=0.5.2 in d:\jupyter\.venv\lib\site-packages (from tavily-python==0.3.3) (0.6.0)
# Requirement already satisfied: regex>=2022.1.18 in d:\jupyter\.venv\lib\site-packages (from tiktoken<1,>=0.5.2->tavily-python==0.3.3) (2024.4.28)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\jupyter\.venv\lib\site-packages (from requests->tavily-python==0.3.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\jupyter\.venv\lib\site-packages (from requests->tavily-python==0.3.3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\jupyter\.venv\lib\site-packages (from requests->tavily-python==0.3.3) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\jupyter\.venv\lib\site-packages (from requests->tavily-python==0.3.3) (2024.2.2)
# Requirement already satisfied: pandas==2.2.2 in d:\jupyter\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\jupyter\.venv\lib\site-packages (from pandas==2.2.2) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\jupyter\.venv\lib\site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\jupyter\.venv\lib\site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\jupyter\.venv\lib\site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: six>=1.5 in d:\jupyter\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.16.0)

# %%
import os
os.environ["TAVILY_API_KEY"] = "<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>"
import uuid
import json
from datetime import datetime

from langchain_community.chat_models import ChatOllama
from langchain_community.embeddings import OllamaEmbeddings
from langchain_core.messages import SystemMessage, AIMessage, HumanMessage
from langchain_core.messages.base import get_msg_title_repr
from langchain_core.prompts import ChatPromptTemplate

from database import Database
from policy import Policy
from online_search import PersianTavilySearchTool
from flight import FlightManager
from llm_translation import translate_to_persian
from llm_translation import replace_fa_numbers_with_en

# %%
class ToolMessage(HumanMessage):
    """Ollama does not support `tool` role and `ToolMessage`"""

    def pretty_repr(self, html: bool = False) -> str:
        title = get_msg_title_repr("Tool" + " Message", bold=html)
        # TODO: handle non-string content.
        if self.name is not None:
            title += f"\nName: {self.name}"
        return f"{title}\n\n{self.content}"


def get_tool_description(tool):
    tool_params = [
        f"{name}: {info['type']} ({info['description']})"
        for name, info in tool.args.items()
    ]
    tool_params_string = ', '.join(tool_params)
    return (
        f"tool_name -> {tool.name}\n"
        f"tool_params -> {tool_params_string}\n"
        f"tool_description ->\n{tool.description}"
    )


llm = ChatOllama(model='llama3', num_ctx=8192, num_thread=8, temperature=0.0)

database = Database(data_dir="storage/database")

policy = Policy(data_dir="storage/policy",llm="llama3", embedding=OllamaEmbeddings(model='llama3'))
policy_tools = policy.get_tools()

flight_manager = FlightManager(database, llm="llama3")
flight_tools = flight_manager.get_tools()

tools = [
    PersianTavilySearchTool(max_results=3, llm=llm),
] + list(policy_tools.values()) + list(flight_tools.values())

tool_descs = '\n\n'.join([get_tool_description(tool) for tool in tools])

# %%
prompt_template = \
"""
You are a helpful Persian customer support assistant for Iran Airlines.
Use the provided tools to search for flights, company policies, and other information to assist the user's queries. 
When searching, be persistent. Expand your query bounds if the first search returns no results. 
If a search comes up empty, expand your search before giving up.

You have access to the following tools to get more information if needed:

{tool_descs}

You also have access to the history of privious messages.

Generate the response in the following json format:
{{
    "THOUGHT": "<you should always think about what to do>",
    "ACTION": "<the action to take, must be one tool_name from above tools>",
    "ACTION_PARAMS": "<the input parameters to the ACTION, it must be in json format complying with the tool_params>"
    "FINAL_ANSWER": "<a text containing the final answer to the original input question>",
}}
If you don't know the answer, you can take an action using one of the provided tools.
But if you do, don't take and action and leave the action-related attributes empty.
The values `ACTION` and `FINAL_ANSWER` can never ever be filled at the same time.

Always make sure that your output is a json complying with above format.
Do NOT add anything before or after the json response.

Current user:\n<User>\n{user_info}\n</User>
Current time: {time}.
"""

# %%
from typing import Dict, Annotated, Any, Optional, Sequence
from typing_extensions import TypedDict

import warnings

from langchain_core.messages import AIMessage, AnyMessage, ToolCall
from langchain_core.runnables import RunnableConfig
from langchain_core.tools import BaseTool
from langgraph.utils import RunnableCallable

from langgraph.checkpoint.sqlite import SqliteSaver
from langgraph.graph import END, StateGraph
from langgraph.prebuilt.tool_node import tools_condition, str_output
from langgraph.graph.message import AnyMessage, Messages, add_messages
from langchain_core.runnables import Runnable, RunnableConfig


class State(TypedDict):
    messages: Annotated[list[AnyMessage], add_messages]


class Assistant:
    def __init__(self, runnable: Runnable):
        self.runnable = runnable

    def __call__(self, state: State, config: RunnableConfig):
        while True:
            result = self.runnable.invoke(state['messages'], config)
            try:
                content_json = json.loads(result.content)
                break
            except ValueError:
                warnings.warn('BAD FORMAT: ' + result.content)
                state['messages'] += [result, HumanMessage("Respond with a json output!")]

        action = content_json.get('ACTION', '').replace(' ', '')
        action_params = content_json.get('ACTION_PARAMS') or {}
        if type(action_params) is str:
            action_params = json.loads(action_params)
        final_answer = content_json.get('FINAL_ANSWER')

        if action:
            tool_call = ToolCall(name=action, args=action_params, id=str(uuid.uuid4()))
            result.tool_calls.append(tool_call)
            return {'messages': result}

        if not final_answer:
            persian_final_answer = ""
        else:
            persian_final_answer = translate_to_persian(final_answer, self.runnable)

        final_result = AIMessage(persian_final_answer)

        return {'messages': [result, final_result]}


class ToolNode(RunnableCallable):

    def __init__(
        self,
        tools: Sequence[BaseTool],
        *,
        name: str = 'tools',
        tags: Optional[list[str]] = None,
    ) -> None:
        super().__init__(self._func, None, name=name, tags=tags, trace=False)
        self.tools_by_name = {tool.name: tool for tool in tools}

    def _func(
        self, input: dict[str, Any], config: RunnableConfig
    ) -> Any:
        message: AnyMessage = input['messages'][-1]
        if not isinstance(message, AIMessage):
            raise ValueError("Last message is not an AIMessage")

        def run_one(call: ToolCall):
            output = self.tools_by_name[call["name"]].invoke(call["args"], config)
            tool_prompt = (
                "Here is the tool results:\n\n" +
                str_output(output)
            )
            return ToolMessage(
                content=tool_prompt, name=call["name"], tool_call_id=call["id"]
            )

        return {"messages": run_one(message.tool_calls[0])}


builder = StateGraph(State)

builder.add_node('assistant', Assistant(llm))
builder.add_node('action', ToolNode(tools))
builder.set_entry_point('assistant')
builder.add_conditional_edges(
    'assistant',
    tools_condition,
    {'action': 'action', END: END},
)
builder.add_edge('action', 'assistant')

memory = SqliteSaver.from_conn_string(':memory:')
graph = builder.compile(checkpointer=memory)

# %%
def _print_event(event: dict, _printed: set, ignore_first_system_message: bool = True):
    current_state = event.get('dialog_state')
    if current_state:
        print(f"Currently in: ", current_state[-1])
    messages = event.get('messages')
    if messages:
        if ignore_first_system_message:
            if isinstance(messages[0], SystemMessage):
                messages = messages[1:]
        for message in messages:
            if message.id not in _printed:
                msg_repr = message.pretty_repr(html=True)
                print(msg_repr)
                _printed.add(message.id)


tutorial_questions = [
    # "ساعت الان چنده؟",
    # "قوانین تهیه بلیط هواپیما چیه؟",
    # "سلام. اطلاعات های مربوط به پروازم رو میخواستم دریافت کنم.",
    # "اطلاعات پروازهای فردا رو میخواستم",
    # "لیست پروازهای به مقصد BSL رو میخواستم",
    # "پروازم رو به هفته آینده انتقال بده",
    # "هزینه اضافه بار برای مسافرت خارجی چقدر است؟",
    "امکانش هست تیکتم رو به شماره ۷۲۴۰۰۰۵۴۳۲۹۰۶۵۶۹ کنسل کنم؟",  # number isuue
    # "قیمت بلیط برای کودکان چقدره؟",  # confusion user/tool
    # "میخواستم تیکتم رو کنسل کنم",  # ???
    # "چه مدت قبل از پرواز هواپیما میشه بلیط تهیه کرد؟",  # hallucinate
    # "حداکثر برای چند نفر میتوان بلیط تهیه کرد؟",  # update/cancel ticket
]

config = {
    'configurable': {
        'passenger_id': '3442 587242',
        'thread_id': str(uuid.uuid4()),
    }
}

database.reset_and_prepare()


_printed = set()
for question in tutorial_questions:
    question=replace_fa_numbers_with_en(question)
    system_message = SystemMessage(prompt_template.format(
        tool_descs=tool_descs, time=datetime.now(),
        user_info=f"passenger_id: {config['configurable']['passenger_id']}"
    ))
    user_message = HumanMessage(question)

    events = graph.stream(
        {'messages': [system_message, user_message]}, config, stream_mode='values'
    )
    for event in events:
        _print_event(event, _printed)
# Out:
# ================================ Human Message =================================
#
# امکانش هست تیکتم رو به شماره 7240005432906569 کنسل کنم؟
# ================================== Ai Message ==================================
#
# { "THOUGHT": "Let's check the ticket cancellation policy and availability of the flight.",
# "ACTION": "cancel_ticket_tool",
# "ACTION_PARAMS": {"ticket_no": "7240005432906569"},
# "FINAL_ANSWER": "" }
# Tool Calls:
#   cancel_ticket_tool (fa575636-39c5-4848-ba17-3d1baab1d8ba)
#  Call ID: fa575636-39c5-4848-ba17-3d1baab1d8ba
#   Args:
#     ticket_no: 7240005432906569
# ================================= Tool Message =================================
# Name: cancel_ticket_tool
#
# Here is the tool results:
#
# Ticket successfully cancelled.
# ================================== Ai Message ==================================
#
# { "THOUGHT": "",
# "ACTION": "",
# "ACTION_PARAMS": {},
# "FINAL_ANSWER": "Your ticket with number 7240005432906569 has been successfully cancelled." }
# ================================== Ai Message ==================================
#
# بillet با شماره ۷۲۴۰۰۰۵۴۳۲۹۰۶۵۶۹ با موفقیت لغو شد.
